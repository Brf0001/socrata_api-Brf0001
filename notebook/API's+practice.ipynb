# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np

# %% [markdown]
# For this project you will use `requests` package and the SODA API to access data through https://data.nashville.gov/. We'll start out with something familiar, the [Top 500 Monthly Searches](https://data.nashville.gov/Public-Services/Nashville-gov-Top-500-Monthly-Searches/fuaa-r5cm), then pull in different datasets further on. You will make different API requests for each individual question.

# %% [markdown]
# Each dataset has its own api endpoint. You can find the endpoint for a dataset by clicking on the `API` button in the top right of the dataset screen, then copying the `API Endpoint`. The default output is `JSON`, which you can leave unchanged:

# %% [markdown]
# Each API is different, so it is very important to read the documentation for each API to know how to use it properly. The documentation for the SODA API is [here](https://dev.socrata.com/consumers/getting-started.html). It is **HIGHLY RECOMMENDED** that you read the documentation before making any requests, then do deeper dives into specific use cases when questions require. NOTE that the examples in the documentation don't use the `requests` package. You will need to look at the examples and figure out which things go in the `url` and which things go in the `params`.

# %%
endpoint = 'https://data.nashville.gov/resource/fuaa-r5cm.json'

response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"month_name":"January","year":"2014","query_count":"223","query_text":"ebid"}\n,{"month_name":"January","year":"2014","query_count":"112","query_text":"property maps"}\n,{"month_name":"January","year":"2014","query_count":"97","query_text":"maps"}\n,{"month_name":"January","year":"2014","query_count":"90","query_text":"property tax"}\n,{"month_name":"January","year":"2014","query_count":"76","query_text":"jobs"}\n,{"month_name":"January","year":"2014","query_count":"75","query_text":"employment"}\n,{"month_name":"January","year":"2014","query_count":"73","query_text":"human resources"}\n,{"month_name":"January","year":"2014","query_count":"62","query_text":"police"}\n,{"month_name":"January","year":"2014","query_count":"61","query_text":"criminal court clerk"}\n,{"month_name":"January","year":"2014","query_count":"53","query_text":"media releases"}\n,{"month_name":"January","year":"2014","query_count":"50","query_text":"property taxes"}\n,{"month_name":"January","year":"2014","query_count":"49","query_text":"gis"}\n,{"month_name":"January","year":"2014","query_count":"46","query_text":"animal control"}\n,{"month_name":"January","year":"2014","query_count":"46","query_text":"traffic signal optimization study"}\n,{"month_name":"January","year":"2014","query_count":"46","query_text":"arrest records"}\n,{"month_name":"January","year":"2014","query_count":"45","query_text":"property assessor"}\n,{"month_name":"January","year":"2014","query_count":"44","query_text":"ess"}\n,{"month_name":"January","year":"2014","query_count":"41","query_text":"water"}\n,{"month_name":"January","year":"2014","query_count":"41","query_text":"zoning"}\n,{"month_name":"January","year":"2014","query_count":"37","query_text":"codes"}\n,{"month_name":"January","year":"2014","query_count":"35","query_text":"criminal court"}\n,{"month_name":"January","year":"2014","query_count":"35","query_text":"inside metro"}\n,{"month_name":"January","year":"2014","query_count":"33","query_text":"parking"}\n,{"month_name":"January","year":"2014","query_count":"30","query_text":"employee self service"}\n,{"month_name":"January","year":"2014","query_count":"29","query_text":"library"}\n,{"month_name":"January","year":"2014","query_count":"29","query_text":"bidding"}\n,{"month_name":"January","year":"2014","query_count":"28","query_text":"accident report"}\n,{"month_name":"January","year":"2014","query_count":"28","query_text":"planning"}\n,{"month_name":"January","year":"2014","query_count":"28","query_text":"pump station"}\n,{"month_name":"January","year":"2014","query_count":"27","query_text":"payroll"}\n,{"month_name":"January","year":"2014","query_count":"27","query_text":"google"}\n,{"month_name":"January","year":"2014","query_count":"27","query_text":"property"}\n,{"month_name":"January","year":"2014","query_count":"26","query_text":"register of deeds"}\n,{"month_name":"January","year":"2014","query_count":"26","query_text":"news media"}\n,{"month_name":"January","year":"2014","query_count":"26","query_text":"traffic management study"}\n,{"month_name":"January","year":"2014","query_count":"26","query_text":"business license"}\n,{"month_name":"January","year":"2014","query_count":"25","query_text":"warrants"}\n,{"month_name":"January","year":"2014","query_count":"25","query_text":"permits"}\n,{"month_name":"January","year":"2014","query_count":"25","query_text":"civil service rules"}\n,{"month_name":"January","year":"2014","query_count":"24","query_text":"inmate search"}\n,{"month_name":"January","year":"2014","query_count":"24","query_text":"civil service"}\n,{"month_name":"January","year":"2014","query_count":"24","query_text":"media release"}\n,{"month_name":"January","year":"2014","query_count":"23","query_text":"careers"}\n,{"month_name":"January","year":"2014","query_count":"23","query_text":"arrests"}\n,{"month_name":"January","year":"2014","query_count":"23","query_text":"police department"}\n,{"month_name":"January","year":"2014","query_count":"22","query_t ...

# %% [markdown]
# 1. Make an API request that returns the months where "fire" was searched in 2016. Which month had the most searches?

# %%
endpoint1 = 'https://data.nashville.gov/resource/fuaa-r5cm.json'

params1 = {
    'Year': 2016,
    'Query Text': 'fire',
}

response1 = requests.get(endpoint1, params = params1)

response1.text
# Out:
# '[{"month_name":"January","year":"2016","query_count":"19","query_text":"fire"}\n,{"month_name":"February","year":"2016","query_count":"35","query_text":"fire"}\n,{"month_name":"March","year":"2016","query_count":"32","query_text":"fire"}\n,{"month_name":"April","year":"2016","query_count":"26","query_text":"fire"}\n,{"month_name":"May","year":"2016","query_count":"24","query_text":"fire"}\n,{"month_name":"June","year":"2016","query_count":"31","query_text":"fire"}\n,{"month_name":"July","year":"2016","query_count":"24","query_text":"fire"}\n,{"month_name":"August","year":"2016","query_count":"47","query_text":"fire"}\n,{"month_name":"September","year":"2016","query_count":"36","query_text":"fire"}\n,{"month_name":"October","year":"2016","query_count":"38","query_text":"fire"}\n,{"month_name":"November","year":"2016","query_count":"32","query_text":"fire"}\n,{"month_name":"December","year":"2016","query_count":"38","query_text":"fire"}]\n'

# %%
res1 = response1.json()
res1
# Out:
# [{'month_name': 'January',
#   'year': '2016',
#   'query_count': '19',
#   'query_text': 'fire'},
#  {'month_name': 'February',
#   'year': '2016',
#   'query_count': '35',
#   'query_text': 'fire'},
#  {'month_name': 'March',
#   'year': '2016',
#   'query_count': '32',
#   'query_text': 'fire'},
#  {'month_name': 'April',
#   'year': '2016',
#   'query_count': '26',
#   'query_text': 'fire'},
#  {'month_name': 'May',
#   'year': '2016',
#   'query_count': '24',
#   'query_text': 'fire'},
#  {'month_name': 'June',
#   'year': '2016',
#   'query_count': '31',
#   'query_text': 'fire'},
#  {'month_name': 'July',
#   'year': '2016',
#   'query_count': '24',
#   'query_text': 'fire'},
#  {'month_name': 'August',
#   'year': '2016',
#   'query_count': '47',
#   'query_text': 'fire'},
#  {'month_name': 'September',
#   'year': '2016',
#   'query_count': '36',
#   'query_text': 'fire'},
#  {'month_name': 'October',
#   'year': '2016',
#   'query_count': '38',
#   'query_text': 'fire'},
#  {'month_name': 'November',
#   'year': '2016',
#   'query_count': '32',
#   'query_text': 'fire'},
#  {'month_name': 'December',
#   'year': '2016',
#   'query_count': '38',
#   'query_text': 'fire'}]

# %%
res1_tab = pd.DataFrame(response1.json())

# %%
maxx = res1_tab['query_count'].max()

# %%
res1_tab[res1_tab['query_count']== maxx]
# Out:
#   month_name  year query_count query_text
# 7     August  2016          47       fire

# %% [markdown]
# 2. Make an API request that returns all the times a query was run more than 100 times in a month. How many times did this occur?

# %%
endpoint2 = 'https://data.nashville.gov/resource/fuaa-r5cm.json'

params2 = {
  '$where': 'query_count > 100',
  '$limit': 200,  
    '$offset': 0
}

response2_data = []

while True:
    response2 = requests.get(endpoint2, params=params2)
    response2_data.extend(response2.json())
    
    if len(response2.json()) < params2['$limit']:
        break
    
    params2['$offset'] += params2['$limit']

print(response2_data)
# Out:
# [{'month_name': 'March', 'year': '2014', 'query_count': '101', 'query_text': 'permits'}, {'month_name': 'January', 'year': '2015', 'query_count': '101', 'query_text': 'criminal court clerk'}, {'month_name': 'September', 'year': '2015', 'query_count': '101', 'query_text': 'codes'}, {'month_name': 'March', 'year': '2016', 'query_count': '101', 'query_text': 'police'}, {'month_name': 'March', 'year': '2016', 'query_count': '101', 'query_text': 'civil service'}, {'month_name': 'November', 'year': '2016', 'query_count': '101', 'query_text': 'jobs'}, {'month_name': 'November', 'year': '2017', 'query_count': '101', 'query_text': 'metro holidays'}, {'month_name': 'November', 'year': '2017', 'query_count': '101', 'query_text': 'longevity pay'}, {'month_name': 'January', 'year': '2018', 'query_count': '101', 'query_text': 'West Nashville Heights Church of Christ'}, {'month_name': 'January', 'year': '2018', 'query_count': '101', 'query_text': 'property maps'}, {'month_name': 'March', 'year': '2018', 'query_count': '101', 'query_text': 'public works'}, {'month_name': 'March', 'year': '2018', 'query_count': '101', 'query_text': 'Payroll'}, {'month_name': 'May', 'year': '2018', 'query_count': '101', 'query_text': 'police report'}, {'month_name': 'June', 'year': '2018', 'query_count': '101', 'query_text': 'criminal court'}, {'month_name': 'June', 'year': '2018', 'query_count': '101', 'query_text': 'payroll'}, {'month_name': 'July', 'year': '2018', 'query_count': '101', 'query_text': 'pay plan'}, {'month_name': 'October', 'year': '2018', 'query_count': '101', 'query_text': 'hr'}, {'month_name': 'April', 'month': '4', 'year': '2019', 'query_count': '101', 'query_text': 'employment'}, {'month_name': 'May', 'month': '5', 'year': '2019', 'query_count': '101', 'query_text': 'police report'}, {'month_name': 'November', 'month': '11', 'year': '2019', 'query_count': '101', 'query_text': 'permits'}, {'month_name': 'November', 'month': '11', 'year': '2019', 'query_count': '101', 'query_text': 'Police'}, {'month_name': 'December', 'month': '12', 'year': '2019', 'query_count': '101', 'query_text': 'birth certificate'}, {'month_name': 'December', 'month': '12', 'year': '2019', 'query_count': '101', 'query_text': 'public works'}, {'month_name': 'January', 'month': '1', 'year': '2020', 'query_count': '101', 'query_text': 'property taxes'}, {'month_name': 'April', 'month': '4', 'year': '2020', 'query_count': '101', 'query_text': 'property maps'}, {'month_name': 'April', 'month': '4', 'year': '2020', 'query_count': '101', 'query_text': 'Public works'}, {'month_name': 'April', 'month': '4', 'year': '2020', 'query_count': '101', 'query_text': 'unemployment'}, {'month_name': 'July', 'month': '7', 'year': '2020', 'query_count': '101', 'query_text': 'Birth certificate'}, {'month_name': 'February', 'month': '2', 'year': '2021', 'query_count': '101', 'query_text': 'Trash pickup'}, {'month_name': 'March', 'month': '3', 'year': '2021', 'query_count': '101', 'query_text': 'Property maps'}, {'month_name': 'May', 'month': '5', 'year': '2021', 'query_count': '101', 'query_text': 'water'}, {'month_name': 'July', 'month': '7', 'year': '2021', 'query_count': '101', 'query_text': 'Birth certificate'}, {'month_name': 'March', 'year': '2014', 'query_count': '102', 'query_text': 'police'}, {'month_name': 'April', 'year': '2014', 'query_count': '102', 'query_text': 'police'}, {'month_name': 'July', 'year': '2014', 'query_count': '102', 'query_text': 'media releases'}, {'month_name': 'August', 'year': '2014', 'query_count': '102', 'query_text': 'employment'}, {'month_name': 'October', 'year': '2015', 'query_count': '102', 'query_text': 'Animal control'}, {'month_name': 'November', 'year': '2015', 'query_count': '102', 'query_text': 'maps'}, {'month_name': 'May', 'year': '2017', 'query_count': '102', 'query_text': 'dcso'}, {'month_name': 'August', 'year': '2017', 'query_count': '102', 'query_text': 'criminal court'}, {'month_name': 'October', 'year': '2017', 'query_count': '102', ' ...

# %%
len(response2_data)
# Out:
# 1262

# %% [markdown]
# 3. Make another API request that returns all the times "codes" was searched more than 100 times in a month. How many times did this occur?

# %%
endpoint3 = 'https://data.nashville.gov/resource/fuaa-r5cm.json'

params3 = {
  '$where': 'query_count> 100 AND query_text == "codes" ',
  '$limit': 200,  
    '$offset': 0
}

response3_data = []

while True:
    response3 = requests.get(endpoint3, params=params3)
    response3_data.extend(response3.json())
    
    if len(response3.json()) < params3['$limit']:
        break
    
    params3['$offset'] += params3['$limit']

print(response3_data)
# Out:
# [{'month_name': 'September', 'year': '2015', 'query_count': '101', 'query_text': 'codes'}, {'month_name': 'April', 'month': '4', 'year': '2021', 'query_count': '102', 'query_text': 'codes'}, {'month_name': 'August', 'year': '2016', 'query_count': '104', 'query_text': 'codes'}, {'month_name': 'November', 'month': '11', 'year': '2020', 'query_count': '104', 'query_text': 'codes'}, {'month_name': 'December', 'year': '2017', 'query_count': '106', 'query_text': 'codes'}, {'month_name': 'May', 'year': '2016', 'query_count': '107', 'query_text': 'codes'}, {'month_name': 'April', 'year': '2016', 'query_count': '111', 'query_text': 'codes'}, {'month_name': 'July', 'month': '7', 'year': '2021', 'query_count': '114', 'query_text': 'codes'}, {'month_name': 'January', 'year': '2017', 'query_count': '115', 'query_text': 'codes'}, {'month_name': 'May', 'month': '5', 'year': '2021', 'query_count': '115', 'query_text': 'codes'}, {'month_name': 'August', 'year': '2015', 'query_count': '117', 'query_text': 'codes'}, {'month_name': 'February', 'year': '2016', 'query_count': '121', 'query_text': 'codes'}, {'month_name': 'February', 'month': '2', 'year': '2019', 'query_count': '124', 'query_text': 'codes'}, {'month_name': 'June', 'month': '6', 'year': '2019', 'query_count': '125', 'query_text': 'codes'}, {'month_name': 'September', 'month': '9', 'year': '2019', 'query_count': '126', 'query_text': 'codes'}, {'month_name': 'January', 'month': '1', 'year': '2019', 'query_count': '129', 'query_text': 'codes'}, {'month_name': 'September', 'month': '9', 'year': '2020', 'query_count': '130', 'query_text': 'codes'}, {'month_name': 'February', 'month': '2', 'year': '2021', 'query_count': '131', 'query_text': 'codes'}, {'month_name': 'March', 'month': '3', 'year': '2019', 'query_count': '133', 'query_text': 'codes'}, {'month_name': 'November', 'month': '11', 'year': '2019', 'query_count': '134', 'query_text': 'codes'}, {'month_name': 'March', 'month': '3', 'year': '2021', 'query_count': '134', 'query_text': 'codes'}, {'month_name': 'November', 'year': '2017', 'query_count': '138', 'query_text': 'codes'}, {'month_name': 'June', 'month': '6', 'year': '2021', 'query_count': '138', 'query_text': 'codes'}, {'month_name': 'October', 'month': '10', 'year': '2020', 'query_count': '139', 'query_text': 'codes'}, {'month_name': 'December', 'month': '12', 'year': '2019', 'query_count': '143', 'query_text': 'codes'}, {'month_name': 'February', 'year': '2017', 'query_count': '150', 'query_text': 'codes'}, {'month_name': 'August', 'month': '8', 'year': '2019', 'query_count': '156', 'query_text': 'codes'}, {'month_name': 'March', 'year': '2017', 'query_count': '158', 'query_text': 'codes'}, {'month_name': 'October', 'month': '10', 'year': '2019', 'query_count': '159', 'query_text': 'codes'}, {'month_name': 'July', 'month': '7', 'year': '2019', 'query_count': '161', 'query_text': 'codes'}, {'month_name': 'January', 'month': '1', 'year': '2020', 'query_count': '161', 'query_text': 'codes'}, {'month_name': 'March', 'month': '3', 'year': '2020', 'query_count': '164', 'query_text': 'codes'}, {'month_name': 'July', 'month': '7', 'year': '2020', 'query_count': '164', 'query_text': 'codes'}, {'month_name': 'December', 'month': '12', 'year': '2020', 'query_count': '165', 'query_text': 'codes'}, {'month_name': 'July', 'year': '2018', 'query_count': '166', 'query_text': 'codes'}, {'month_name': 'September', 'year': '2017', 'query_count': '168', 'query_text': 'codes'}, {'month_name': 'April', 'month': '4', 'year': '2019', 'query_count': '168', 'query_text': 'codes'}, {'month_name': 'April', 'year': '2018', 'query_count': '170', 'query_text': 'codes'}, {'month_name': 'September', 'year': '2018', 'query_count': '171', 'query_text': 'codes'}, {'month_name': 'October', 'year': '2018', 'query_count': '174', 'query_text': 'codes'}, {'month_name': 'August', 'month': '8', 'year': '2020', 'query_count': '178', 'query_text': 'codes'}, {'month_name': 'February', 'month': '2', 'year': '2020', 'que ...

# %%
len(response3_data)
# Out:
# 56

# %% [markdown]
# 4. Make an API request that returns the entire Top 500 Monthly Searches dataset. Make a chart that shows the number of times "maps" was searched in a month across the entire time frame.

# %%
endpoint4 = 'https://data.nashville.gov/resource/fuaa-r5cm.json'

params4 = {
    '$where': 'query_text == "maps"',
    '$limit': 200,  
    '$offset': 0
}

response4_data = []

while True:
    response4 = requests.get(endpoint4, params=params4)
    response4_data.extend(response4.json())
    
    if len(response4.json()) < params4['$limit']:
        break
    
    params4['$offset'] += params4['$limit']

print(response4_data)
# Out:
# [{'month_name': 'January', 'year': '2014', 'query_count': '97', 'query_text': 'maps'}, {'month_name': 'February', 'year': '2014', 'query_count': '140', 'query_text': 'maps'}, {'month_name': 'March', 'year': '2014', 'query_count': '144', 'query_text': 'maps'}, {'month_name': 'April', 'year': '2014', 'query_count': '152', 'query_text': 'maps'}, {'month_name': 'May', 'year': '2014', 'query_count': '119', 'query_text': 'maps'}, {'month_name': 'June', 'year': '2014', 'query_count': '121', 'query_text': 'maps'}, {'month_name': 'July', 'year': '2014', 'query_count': '121', 'query_text': 'maps'}, {'month_name': 'August', 'year': '2014', 'query_count': '118', 'query_text': 'maps'}, {'month_name': 'September', 'year': '2014', 'query_count': '115', 'query_text': 'maps'}, {'month_name': 'October', 'year': '2014', 'query_count': '100', 'query_text': 'maps'}, {'month_name': 'November', 'year': '2014', 'query_count': '82', 'query_text': 'maps'}, {'month_name': 'December', 'year': '2014', 'query_count': '97', 'query_text': 'maps'}, {'month_name': 'January', 'year': '2015', 'query_count': '119', 'query_text': 'maps'}, {'month_name': 'February', 'year': '2015', 'query_count': '129', 'query_text': 'maps'}, {'month_name': 'April', 'year': '2015', 'query_count': '130', 'query_text': 'maps'}, {'month_name': 'May', 'year': '2015', 'query_count': '109', 'query_text': 'maps'}, {'month_name': 'January', 'year': '2017', 'query_count': '117', 'query_text': 'maps'}, {'month_name': 'July', 'year': '2015', 'query_count': '120', 'query_text': 'maps'}, {'month_name': 'June', 'year': '2015', 'query_count': '148', 'query_text': 'maps'}, {'month_name': 'August', 'year': '2015', 'query_count': '81', 'query_text': 'maps'}, {'month_name': 'September', 'year': '2015', 'query_count': '110', 'query_text': 'maps'}, {'month_name': 'October', 'year': '2015', 'query_count': '110', 'query_text': 'maps'}, {'month_name': 'November', 'year': '2015', 'query_count': '102', 'query_text': 'maps'}, {'month_name': 'December', 'year': '2015', 'query_count': '117', 'query_text': 'maps'}, {'month_name': 'January', 'year': '2016', 'query_count': '104', 'query_text': 'maps'}, {'month_name': 'February', 'year': '2016', 'query_count': '130', 'query_text': 'maps'}, {'month_name': 'March', 'year': '2016', 'query_count': '83', 'query_text': 'maps'}, {'month_name': 'April', 'year': '2016', 'query_count': '115', 'query_text': 'maps'}, {'month_name': 'May', 'year': '2016', 'query_count': '125', 'query_text': 'maps'}, {'month_name': 'June', 'year': '2016', 'query_count': '125', 'query_text': 'maps'}, {'month_name': 'July', 'year': '2016', 'query_count': '149', 'query_text': 'maps'}, {'month_name': 'August', 'year': '2016', 'query_count': '137', 'query_text': 'maps'}, {'month_name': 'September', 'year': '2016', 'query_count': '181', 'query_text': 'maps'}, {'month_name': 'October', 'year': '2016', 'query_count': '138', 'query_text': 'maps'}, {'month_name': 'November', 'year': '2016', 'query_count': '120', 'query_text': 'maps'}, {'month_name': 'December', 'year': '2016', 'query_count': '108', 'query_text': 'maps'}, {'month_name': 'February', 'year': '2017', 'query_count': '235', 'query_text': 'maps'}, {'month_name': 'March', 'year': '2017', 'query_count': '331', 'query_text': 'maps'}, {'month_name': 'April', 'year': '2017', 'query_count': '351', 'query_text': 'maps'}, {'month_name': 'May', 'year': '2017', 'query_count': '266', 'query_text': 'maps'}, {'month_name': 'June', 'year': '2017', 'query_count': '265', 'query_text': 'maps'}, {'month_name': 'July', 'year': '2017', 'query_count': '236', 'query_text': 'maps'}, {'month_name': 'August', 'year': '2017', 'query_count': '238', 'query_text': 'maps'}, {'month_name': 'September', 'year': '2017', 'query_count': '222', 'query_text': 'maps'}, {'month_name': 'October', 'year': '2017', 'query_count': '224', 'query_text': 'maps'}, {'month_name': 'November', 'year': '2017', 'query_count': '155', 'query_text': 'maps'}, {'month_name': 'December', 'year': '2017' ...

# %%
response4_data
# Out:
# [{'month_name': 'January',
#   'year': '2014',
#   'query_count': '97',
#   'query_text': 'maps'},
#  {'month_name': 'February',
#   'year': '2014',
#   'query_count': '140',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'year': '2014',
#   'query_count': '144',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'year': '2014',
#   'query_count': '152',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'year': '2014',
#   'query_count': '119',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'year': '2014',
#   'query_count': '121',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'year': '2014',
#   'query_count': '121',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'year': '2014',
#   'query_count': '118',
#   'query_text': 'maps'},
#  {'month_name': 'September',
#   'year': '2014',
#   'query_count': '115',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'year': '2014',
#   'query_count': '100',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'year': '2014',
#   'query_count': '82',
#   'query_text': 'maps'},
#  {'month_name': 'December',
#   'year': '2014',
#   'query_count': '97',
#   'query_text': 'maps'},
#  {'month_name': 'January',
#   'year': '2015',
#   'query_count': '119',
#   'query_text': 'maps'},
#  {'month_name': 'February',
#   'year': '2015',
#   'query_count': '129',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'year': '2015',
#   'query_count': '130',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'year': '2015',
#   'query_count': '109',
#   'query_text': 'maps'},
#  {'month_name': 'January',
#   'year': '2017',
#   'query_count': '117',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'year': '2015',
#   'query_count': '120',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'year': '2015',
#   'query_count': '148',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'year': '2015',
#   'query_count': '81',
#   'query_text': 'maps'},
#  {'month_name': 'September',
#   'year': '2015',
#   'query_count': '110',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'year': '2015',
#   'query_count': '110',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'year': '2015',
#   'query_count': '102',
#   'query_text': 'maps'},
#  {'month_name': 'December',
#   'year': '2015',
#   'query_count': '117',
#   'query_text': 'maps'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '104',
#   'query_text': 'maps'},
#  {'month_name': 'February',
#   'year': '2016',
#   'query_count': '130',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'year': '2016',
#   'query_count': '83',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'year': '2016',
#   'query_count': '115',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'year': '2016',
#   'query_count': '125',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'year': '2016',
#   'query_count': '125',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'year': '2016',
#   'query_count': '149',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'year': '2016',
#   'query_count': '137',
#   'query_text': 'maps'},
#  {'month_name': 'September',
#   'year': '2016',
#   'query_count': '181',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'year': '2016',
#   'query_count': '138',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'year': '2016',
#   'query_count': '120',
#   'query_text': 'maps'},
#  {'month_name': 'December',
#   'year': '2016',
#   'query_count': '108',
#   'query_text': 'maps'},
#  {'month_name': 'February',
#   'year': '2017',
#   'query_count': '235',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'year': '2017',
#   'query_count': '331',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'year': '2017',
#   'query_count': '351',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'year': '2017',
#   'query_count': '266',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'year': '2017',
#   'query_count': '265',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'year': '2017',
#   'query_count': '236',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'year': '2017',
#   'query_count': '238',
#   'query_text': 'maps'},
#  {'month_name': 'September',
#   'year': '2017',
#   'query_count': '222',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'year': '2017',
#   'query_count': '224',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'year': '2017',
#   'query_count': '155',
#   'query_text': 'maps'},
#  {'month_name': 'December',
#   'year': '2017',
#   'query_count': '121',
#   'query_text': 'maps'},
#  {'month_name': 'January',
#   'year': '2018',
#   'query_count': '173',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'year': '2018',
#   'query_count': '188',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'year': '2018',
#   'query_count': '189',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'year': '2018',
#   'query_count': '156',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'year': '2018',
#   'query_count': '154',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'year': '2018',
#   'query_count': '173',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'year': '2018',
#   'query_count': '186',
#   'query_text': 'maps'},
#  {'month_name': 'September',
#   'year': '2018',
#   'query_count': '240',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'year': '2018',
#   'query_count': '166',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'year': '2018',
#   'query_count': '164',
#   'query_text': 'maps'},
#  {'month_name': 'January',
#   'month': '1',
#   'year': '2019',
#   'query_count': '160',
#   'query_text': 'maps'},
#  {'month_name': 'February',
#   'month': '2',
#   'year': '2019',
#   'query_count': '98',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'month': '3',
#   'year': '2019',
#   'query_count': '88',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'month': '4',
#   'year': '2019',
#   'query_count': '110',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'month': '5',
#   'year': '2019',
#   'query_count': '105',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'month': '6',
#   'year': '2019',
#   'query_count': '116',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'month': '7',
#   'year': '2019',
#   'query_count': '124',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'month': '8',
#   'year': '2019',
#   'query_count': '106',
#   'query_text': 'maps'},
#  {'month_name': 'September',
#   'month': '9',
#   'year': '2019',
#   'query_count': '83',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'month': '10',
#   'year': '2019',
#   'query_count': '116',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'month': '11',
#   'year': '2019',
#   'query_count': '96',
#   'query_text': 'maps'},
#  {'month_name': 'January',
#   'month': '1',
#   'year': '2020',
#   'query_count': '154',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'month': '3',
#   'year': '2020',
#   'query_count': '124',
#   'query_text': 'maps'},
#  {'month_name': 'February',
#   'month': '2',
#   'year': '2020',
#   'query_count': '100',
#   'query_text': 'maps'},
#  {'month_name': 'May',
#   'month': '5',
#   'year': '2020',
#   'query_count': '139',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'month': '4',
#   'year': '2020',
#   'query_count': '114',
#   'query_text': 'maps'},
#  {'month_name': 'July',
#   'month': '7',
#   'year': '2020',
#   'query_count': '139',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'month': '6',
#   'year': '2020',
#   'query_count': '136',
#   'query_text': 'maps'},
#  {'month_name': 'August',
#   'month': '8',
#   'year': '2020',
#   'query_count': '125',
#   'query_text': 'maps'},
#  {'month_name': 'October',
#   'month': '10',
#   'year': '2020',
#   'query_count': '127',
#   'query_text': 'maps'},
#  {'month_name': 'November',
#   'month': '11',
#   'year': '2020',
#   'query_count': '86',
#   'query_text': 'maps'},
#  {'month_name': 'December',
#   'month': '12',
#   'year': '2020',
#   'query_count': '113',
#   'query_text': 'maps'},
#  {'month_name': 'March',
#   'month': '3',
#   'year': '2021',
#   'query_count': '132',
#   'query_text': 'maps'},
#  {'month_name': 'April',
#   'month': '4',
#   'year': '2021',
#   'query_count': '148',
#   'query_text': 'maps'},
#  {'month_name': 'June',
#   'month': '6',
#   'year': '2021',
#   'query_count': '151',
#   'query_text': 'maps'}]

# %%
res4_tab = pd.DataFrame(response4_data)

# %%
len(res4_tab)
# Out:
# 82

# %%
month_order = ['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
res4_tab['month_name']= pd.Categorical(res4_tab['month_name'],categories=month_order,ordered=True)

# %%
grap = res4_tab.pivot_table(index='month_name',columns='year',values='query_count')

# %%
graph = grap.fillna(0)

# %%
graph
# Out:
# year         2014   2015   2016   2017   2018   2019   2020   2021
# month_name
# January      97.0  119.0  104.0  117.0  173.0  160.0  154.0    0.0
# February    140.0  129.0  130.0  235.0    0.0   98.0  100.0    0.0
# March       144.0    0.0   83.0  331.0  188.0   88.0  124.0  132.0
# April       152.0  130.0  115.0  351.0  189.0  110.0  114.0  148.0
# May         119.0  109.0  125.0  266.0  156.0  105.0  139.0    0.0
# June        121.0  148.0  125.0  265.0  154.0  116.0  136.0  151.0
# July        121.0  120.0  149.0  236.0  173.0  124.0  139.0    0.0
# August      118.0   81.0  137.0  238.0  186.0  106.0  125.0    0.0
# September   115.0  110.0  181.0  222.0  240.0   83.0    0.0    0.0
# October     100.0  110.0  138.0  224.0  166.0  116.0  127.0    0.0
# November     82.0  102.0  120.0  155.0  164.0   96.0   86.0    0.0
# December     97.0  117.0  108.0  121.0    0.0    0.0  113.0    0.0

# %% [markdown]
# 5. Make an API request to pull back all the data from [hubNashville (311) Service Requests](https://data.nashville.gov/Public-Services/hubNashville-311-Service-Requests/7qhx-rexh) (check to see how many rows you can return in a single request). Compare it to the Top 500 Monthly Searches data set. What do you observe? (This is open-ended, there isn't a specific answer for this one)

# %%
endpoint5 = 'https://data.nashville.gov/resource/7qhx-rexh.json'

params5 = {
  
}

response5 = requests.get(endpoint5, params = params5)

response5.text
# Out:
# '[{"case_number":"966190","status":"Closed","case_request":"Resolved by hubNashville on First Call","case_subrequest":"Resolved by hubNashville on First Call","additional_subrequest":"Resolved by hubNashville on First Call","date_time_opened":"2022-05-04T17:54:30.000","date_time_closed":"2022-05-04T17:54:30.000","case_origin":"Phone","state_issue":"False","closed_when_created":"True","incident_address":"1301 Pilgrim Dr","incident_city":"MADISON","incident_council_district":"8","incident_zip_code":"37115","latitude":"36.2718801","longitude":"-86.7175492","mapped_location":{"latitude":"36.2718801","longitude":"-86.7175492"},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"3",":@computed_region_gxvr_9jxz":"12",":@computed_region_yf9r_ed6g":"3",":@computed_region_fvtq_wnma":"26",":@computed_region_s8bq_67w7":"3",":@computed_region_v67z_xm3t":"2",":@computed_region_kh5x_g7w5":"3",":@computed_region_cfa7_hbpz":"71",":@computed_region_sjpq_96s8":"1527",":@computed_region_gisn_y5cm":"4",":@computed_region_b9k3_hpc2":"2"}\n,{"case_number":"932934","status":"Closed","case_request":"Public Safety","case_subrequest":"Abandoned Vehicles","additional_subrequest":"Abandoned Vehicles","date_time_opened":"2022-04-01T21:01:39.000","date_time_closed":"2022-04-05T11:29:54.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"1237 Tuckahoe Dr","incident_city":"NASHVILLE","incident_council_district":"3","incident_zip_code":"37207","latitude":"36.25727","longitude":"-86.76369","mapped_location":{"latitude":"36.25727","longitude":"-86.76369"},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"2",":@computed_region_p6sk_2acq":"16",":@computed_region_gxvr_9jxz":"16",":@computed_region_yf9r_ed6g":"9",":@computed_region_fvtq_wnma":"31",":@computed_region_s8bq_67w7":"13",":@computed_region_v67z_xm3t":"1",":@computed_region_kh5x_g7w5":"9",":@computed_region_cfa7_hbpz":"1018",":@computed_region_sjpq_96s8":"15550",":@computed_region_gisn_y5cm":"4",":@computed_region_b9k3_hpc2":"1"}\n,{"case_number":"932939","status":"Closed","case_request":"Trash, Recycling & Litter","case_subrequest":"Cart Service","additional_subrequest":"Trash - Report a Damaged Cart","date_time_opened":"2022-04-01T21:04:50.000","date_time_closed":"2022-04-06T20:14:15.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"3613 Wells Ct","incident_city":"ANTIOCH","incident_council_district":"33","incident_zip_code":"37013","latitude":"36.080968","longitude":"-86.602406","mapped_location":{"latitude":"36.080968","longitude":"-86.602406"},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"33",":@computed_region_gxvr_9jxz":"15",":@computed_region_yf9r_ed6g":"33",":@computed_region_fvtq_wnma":"2",":@computed_region_s8bq_67w7":"33",":@computed_region_v67z_xm3t":"8",":@computed_region_kh5x_g7w5":"33",":@computed_region_cfa7_hbpz":"258",":@computed_region_sjpq_96s8":"24062",":@computed_region_gisn_y5cm":"7",":@computed_region_b9k3_hpc2":"8"}\n,{"case_number":"932935","status":"Closed","case_request":"Resolved by hubNashville on First Call","case_subrequest":"Resolved by hubNashville on First Call","additional_subrequest":"Resolved by hubNashville on First Call","date_time_opened":"2022-04-01T21:01:47.000","date_time_closed":"2022-04-01T21:01:47.000","case_origin":"Phone","state_issue":"False","closed_when_created":"True"}\n,{"case_number":"932938","status":"Closed","case_request":"Public Safety","case_subrequest":"Request Non-Emergency Police Assistance","date_time_opened":"2022-04-01T21:03:10.000","date_time_closed":"2022-04-01T22:04:31.000","case_origin":"Phone","state_issue":"False","closed_when_created":"False","incident_address":"401 Broadway","incident_city":"NASHVILLE","incident_council_district":"19","incident_zip_code":"37203","latitude":"36.16074","longitude":"-86.77726","mapped_location": ...

# %%
res5 = response5.json()

# %%
res5_tab = pd.DataFrame(res5)

# %%
res5_tab.head(2)
# Out:
#   case_number  status                            case_request  \
# 0      966190  Closed  Resolved by hubNashville on First Call
# 1      932934  Closed                           Public Safety
#
#                           case_subrequest  \
# 0  Resolved by hubNashville on First Call
# 1                      Abandoned Vehicles
#
#                     additional_subrequest         date_time_opened  \
# 0  Resolved by hubNashville on First Call  2022-05-04T17:54:30.000
# 1                      Abandoned Vehicles  2022-04-01T21:01:39.000
#
#           date_time_closed case_origin state_issue closed_when_created  ...  \
# 0  2022-05-04T17:54:30.000       Phone       False                True  ...
# 1  2022-04-05T11:29:54.000       Phone       False               False  ...
#
#   :@computed_region_s8bq_67w7 :@computed_region_v67z_xm3t  \
# 0                           3                           2
# 1                          13                           1
#
#   :@computed_region_kh5x_g7w5 :@computed_region_cfa7_hbpz  \
# 0                           3                          71
# 1                           9                        1018
#
#   :@computed_region_sjpq_96s8 :@computed_region_gisn_y5cm  \
# 0                        1527                           4
# 1                       15550                           4
#
#   :@computed_region_b9k3_hpc2 oem_id contact_type parent_case
# 0                           2    NaN          NaN         NaN
# 1                           1    NaN          NaN         NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# 6. Find 2 new data sets on data.nashville.gov, make API requests to pull the data, and do an analysis that combines the data sets.

# %%
endpoint6 = 'https://data.nashville.gov/resource/a5tp-4w2v.json'

params6 = {
  
}

response6 = requests.get(endpoint6, params = params6)

response6.text
# Out:
# '[{"initiated_date":"2023-01-18T15:05:11.000","permit":"202302128","permit_type":"LANE CLOSURE","permit_description":"MOBILE FOOD TRUCK","status":"ACTIVE","on_street":"DEADERICK ST","from_street":"2ND AV N","to_street":"4TH AV N","location_address":"DEADERICK ST","city":"NASHVILLE","zip":"37201","scope":"MOBILE FOOD TRUCK","scheduled_start":"2023-01-18T00:00:00.000","scheduled_end":"2023-06-17T00:00:00.000","permit_applicant_name":"RATRI SARAWAN","council_district":"19","conditions_traffic_control":"Parking of mobile food truck in any of the authorized food truck zones","company":"Momma Joys Hot Chicken and Plus More","days_to_work":"Monday Tuesday Wednesday Thursday Friday Saturday Sunday,","latitude":"36.1662405591285","longitude":"-86.779409317216","mapped_location":{"type":"Point","coordinates":[-86.779409317216,36.1662405591285]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"20",":@computed_region_gxvr_9jxz":"29",":@computed_region_b9k3_hpc2":"7"}\n,{"initiated_date":"2023-02-09T11:47:34.000","permit":"202305185","permit_type":"DRIVEWAY PERMIT","permit_description":"POURING ENTRANCE AND APRON TO DRIVEWAY","status":"ACTIVE","on_street":"4108 WESTLAWN DR","from_street":"WESTLAWN PL","to_street":"WESTLAWN CT","location_address":"4108 WESTLAWN DR","city":"NASHVILLE","zip":"37209","scope":"POURING ENTRANCE AND APRON TO DRIVEWAY","scheduled_start":"2023-03-01T00:00:00.000","scheduled_end":"2024-02-28T00:00:00.000","permit_applicant_name":"CHRISTY CONWAY","council_district":"24","conditions_traffic_control":"Proofroll subgrade  Maintain Local Access  Daylight Hours Only","company":"Christy Conway","days_to_work":"Monday Tuesday Wednesday Thursday Friday Saturday Sunday,","latitude":"36.1393235314126","longitude":"-86.836318688412","mapped_location":{"type":"Point","coordinates":[-86.836318688412,36.1393235314126]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"10",":@computed_region_gxvr_9jxz":"46",":@computed_region_b9k3_hpc2":"5"}\n,{"initiated_date":"2023-02-13T10:29:20.000","permit":"202305635","permit_type":"EXCAVATION PERMIT","permit_description":"WATER AND SEWER TAP","status":"ACTIVE","on_street":"3503 RICHARDS ST","from_street":"WOODMONT BLVD","to_street":"GRAYBAR LN","location_address":"3503 RICHARDS ST","city":"NASHVILLE","zip":"37215","scope":"WATER AND SEWER TAP","scheduled_start":"2023-04-11T00:00:00.000","scheduled_end":"2023-07-10T00:00:00.000","permit_applicant_name":"JASON AYERS","council_district":"25","conditions_traffic_control":"cc.\\tPost the permit in the front window of the vehicle  dd.\\tText a picture of the parked vehicle with the posted permit to the inspector listed on the permit","company":"APS Contractors LLC","days_to_work":"Monday Tuesday Wednesday Thursday Friday Saturday Sunday,","latitude":"36.1125458177089","longitude":"-86.8017289331829","mapped_location":{"type":"Point","coordinates":[-86.8017289331829,36.1125458177089]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"11",":@computed_region_gxvr_9jxz":"47",":@computed_region_b9k3_hpc2":"6"}\n,{"initiated_date":"2023-03-09T14:00:40.000","permit":"202308983","permit_type":"EXCAVATION PERMIT","permit_description":"REPAIR WATER MAIN","status":"ACTIVE","on_street":"795 NORWOOD DR","from_street":"FRANKLIN PIKE","to_street":"DEAD END","location_address":"795 NORWOOD DR","city":"NASHVILLE","zip":"37204","scope":"REPAIR WATER MAIN","scheduled_start":"2023-03-09T00:00:00.000","scheduled_end":"2023-06-07T00:00:00.000","permit_applicant_name":"FRANK MADDEN","council_district":"25","company":"METRO WATER","days_to_work":"Monday Tuesday Wednesday Thursday Friday Saturday Sunday,","latitude":"36.0988351293242","longitude":"-86.7716657580695","mapped_location":{"type":"Point","coordinates":[-86.7716657580695,36.0988351293242]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"2",":@comput ...

# %%
res6 = response6.json()

# %%
res6_tab = pd.DataFrame(res6)

# %%
print(res6_tab.columns)
# Out:
# Index(['initiated_date', 'permit', 'permit_type', 'permit_description',
#        'status', 'on_street', 'from_street', 'to_street', 'location_address',
#        'city', 'zip', 'scope', 'scheduled_start', 'scheduled_end',
#        'permit_applicant_name', 'council_district',
#        'conditions_traffic_control', 'company', 'days_to_work', 'latitude',
#        'longitude', 'mapped_location', ':@computed_region_wvby_4s8j',
#        ':@computed_region_3aw5_2wv7', ':@computed_region_p6sk_2acq',
#        ':@computed_region_gxvr_9jxz', ':@computed_region_b9k3_hpc2'],
#       dtype='object')

# %%
res6_tab.head(2)
# Out:
#             initiated_date     permit      permit_type  \
# 0  2023-01-18T15:05:11.000  202302128     LANE CLOSURE
# 1  2023-02-09T11:47:34.000  202305185  DRIVEWAY PERMIT
#
#                        permit_description  status         on_street  \
# 0                       MOBILE FOOD TRUCK  ACTIVE      DEADERICK ST
# 1  POURING ENTRANCE AND APRON TO DRIVEWAY  ACTIVE  4108 WESTLAWN DR
#
#    from_street    to_street  location_address       city  ...  \
# 0     2ND AV N     4TH AV N      DEADERICK ST  NASHVILLE  ...
# 1  WESTLAWN PL  WESTLAWN CT  4108 WESTLAWN DR  NASHVILLE  ...
#
#                                 company  \
# 0  Momma Joys Hot Chicken and Plus More
# 1                        Christy Conway
#
#                                         days_to_work          latitude  \
# 0  Monday Tuesday Wednesday Thursday Friday Satur...  36.1662405591285
# 1  Monday Tuesday Wednesday Thursday Friday Satur...  36.1393235314126
#
#           longitude                                    mapped_location  \
# 0  -86.779409317216  {'type': 'Point', 'coordinates': [-86.77940931...
# 1  -86.836318688412  {'type': 'Point', 'coordinates': [-86.83631868...
#
#   :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                           1                           1
# 1                           1                           1
#
#   :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz  \
# 0                          20                          29
# 1                          10                          46
#
#   :@computed_region_b9k3_hpc2
# 0                           7
# 1                           5
#
# [2 rows x 27 columns]

# %%
endpoint62 = 'https://data.nashville.gov/resource/479w-kw2x.json'

params62 = {
  
}

response62 = requests.get(endpoint62, params = params62)

response62.text
# Out:
# '[{"request":"22-1294689","date_received":"2022-04-19T00:00:00.000","property_apn":"081084A90000CO","property_address":"1720  6TH AVE N","city":"NASHVILLE","state":"TN","zip":"37208","property_owner":"O.I.C. 1720 6TH AVENUE NORTH TOWNHOMES","complaint_source":"HUB","reported_problem":"Type: Property Violations - Junk and Debris  Description:  Lots of junk and debris that has been sitting in the rear yard of 1720 A 6th Ave North for months.  Please make this property owner clean up her property! Click the link below for photo. https://www.dropbox.com/s/7g2lgvmjdr1elfi/1720%20A%206th%20Ave%20N.jpg?dl=0  Additional Comments:","status":"DONE","council_district":"19","last_activity_date":"2022-05-02T00:00:00.000","last_activity":"PS - Close Out Reason","last_activity_result":"DONE","mapped_location":{"latitude":"36.18265","longitude":"-86.79448","human_address":"{\\"address\\": \\"1720 6TH AVE N\\", \\"city\\": \\"NASHVILLE\\", \\"state\\": \\"TN\\", \\"zip\\": \\"37208\\"}"},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"20",":@computed_region_gxvr_9jxz":"51",":@computed_region_gisn_y5cm":"6",":@computed_region_v3ji_vzam":"2005",":@computed_region_c9xn_skx3":"13",":@computed_region_cfa7_hbpz":"89",":@computed_region_f73m_vb2k":"1",":@computed_region_kh5x_g7w5":"13",":@computed_region_yf9r_ed6g":"13",":@computed_region_fvtq_wnma":"24",":@computed_region_b9k3_hpc2":"1"}\n,{"request":"21-1282201","date_received":"2021-12-03T00:00:00.000","property_apn":"08302029400","property_address":"304  CHAPEL AVE","city":"NASHVILLE","state":"TN","zip":"37206","property_owner":"MDHA","complaint_source":"INSPECTOR REPORTED","reported_problem":"VROW","status":"DONE","council_district":"6","last_activity_date":"2021-12-14T00:00:00.000","last_activity":"Violation Inspection CAR - PS","last_activity_result":"Violation Resolved","violations_noted":"VEHICLE IN THE RIGHT OF WAY","mapped_location":{"latitude":"36.186814","longitude":"-86.73742","human_address":"{\\"address\\": \\"304 CHAPEL AVE\\", \\"city\\": \\"NASHVILLE\\", \\"state\\": \\"TN\\", \\"zip\\": \\"37206\\"}"},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"14",":@computed_region_gxvr_9jxz":"4",":@computed_region_gisn_y5cm":"2",":@computed_region_sjpq_96s8":"15548",":@computed_region_v3ji_vzam":"2005",":@computed_region_c9xn_skx3":"7",":@computed_region_cfa7_hbpz":"13",":@computed_region_f73m_vb2k":"7",":@computed_region_kh5x_g7w5":"7",":@computed_region_yf9r_ed6g":"7",":@computed_region_fvtq_wnma":"50",":@computed_region_b9k3_hpc2":"7"}\n,{"request":"21-1277394","date_received":"2021-10-05T00:00:00.000","property_apn":"06100004700","property_address":"2701  OAKWOOD AVE","city":"NASHVILLE","state":"TN","zip":"37207","property_owner":"METRO GOV\'T  P  OAKWOOD","complaint_source":"INSPECTOR REPORTED","reported_problem":"AMV","status":"DONE","council_district":"8","last_activity_date":"2021-12-14T00:00:00.000","last_activity":"Vehicle ROW Final - PS","last_activity_result":"Violation Resolved","mapped_location":{"latitude":"36.213924","longitude":"-86.753348","human_address":"{\\"address\\": \\"2701 OAKWOOD AVE\\", \\"city\\": \\"NASHVILLE\\", \\"state\\": \\"TN\\", \\"zip\\": \\"37207\\"}"},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"3",":@computed_region_gxvr_9jxz":"16",":@computed_region_gisn_y5cm":"2",":@computed_region_sjpq_96s8":"15550",":@computed_region_v3ji_vzam":"2005",":@computed_region_c9xn_skx3":"3",":@computed_region_cfa7_hbpz":"472",":@computed_region_f73m_vb2k":"2",":@computed_region_kh5x_g7w5":"3",":@computed_region_yf9r_ed6g":"3",":@computed_region_fvtq_wnma":"31",":@computed_region_b9k3_hpc2":"2"}\n,{"request":"21-1283105","date_received":"2021-12-14T00:00:00.000","property_apn":"07104014700","property_address":"0  KINGSTON ST","city":"NASHVILLE","state":"TN","zip":"37207","property_owner":"MCMURTRY, JAMES E.","complain ...

# %%
res62 = response62.json()

# %%
res62_tab = pd.DataFrame(res62)

# %%
print(res62_tab.columns)
# Out:
# Index(['request', 'date_received', 'property_apn', 'property_address', 'city',
#        'state', 'zip', 'property_owner', 'complaint_source',
#        'reported_problem', 'status', 'council_district', 'last_activity_date',
#        'last_activity', 'last_activity_result', 'mapped_location',
#        ':@computed_region_wvby_4s8j', ':@computed_region_3aw5_2wv7',
#        ':@computed_region_p6sk_2acq', ':@computed_region_gxvr_9jxz',
#        ':@computed_region_gisn_y5cm', ':@computed_region_v3ji_vzam',
#        ':@computed_region_c9xn_skx3', ':@computed_region_cfa7_hbpz',
#        ':@computed_region_f73m_vb2k', ':@computed_region_kh5x_g7w5',
#        ':@computed_region_yf9r_ed6g', ':@computed_region_fvtq_wnma',
#        ':@computed_region_b9k3_hpc2', 'violations_noted',
#        ':@computed_region_sjpq_96s8'],
#       dtype='object')

# %%
res62_tab.head(2)
# Out:
#       request            date_received    property_apn property_address  \
# 0  22-1294689  2022-04-19T00:00:00.000  081084A90000CO  1720  6TH AVE N
# 1  21-1282201  2021-12-03T00:00:00.000     08302029400  304  CHAPEL AVE
#
#         city state    zip                          property_owner  \
# 0  NASHVILLE    TN  37208  O.I.C. 1720 6TH AVENUE NORTH TOWNHOMES
# 1  NASHVILLE    TN  37206                                    MDHA
#
#      complaint_source                                   reported_problem  ...  \
# 0                 HUB  Type: Property Violations - Junk and Debris  D...  ...
# 1  INSPECTOR REPORTED                                               VROW  ...
#
#   :@computed_region_v3ji_vzam :@computed_region_c9xn_skx3  \
# 0                        2005                          13
# 1                        2005                           7
#
#   :@computed_region_cfa7_hbpz :@computed_region_f73m_vb2k  \
# 0                          89                           1
# 1                          13                           7
#
#   :@computed_region_kh5x_g7w5 :@computed_region_yf9r_ed6g  \
# 0                          13                          13
# 1                           7                           7
#
#   :@computed_region_fvtq_wnma :@computed_region_b9k3_hpc2  \
# 0                          24                           1
# 1                          50                           7
#
#               violations_noted :@computed_region_sjpq_96s8
# 0                          NaN                         NaN
# 1  VEHICLE IN THE RIGHT OF WAY                       15548
#
# [2 rows x 31 columns]

# %%
zip37208_comp = res62_tab[res62_tab['zip']=='37208']

# %%
zip37208_perm = res6_tab[res6_tab['zip']=='37208']

# %%
zip37208_comp.head(1)
# Out:
#       request            date_received    property_apn property_address  \
# 0  22-1294689  2022-04-19T00:00:00.000  081084A90000CO  1720  6TH AVE N
#
#         city state    zip                          property_owner  \
# 0  NASHVILLE    TN  37208  O.I.C. 1720 6TH AVENUE NORTH TOWNHOMES
#
#   complaint_source                                   reported_problem  ...  \
# 0              HUB  Type: Property Violations - Junk and Debris  D...  ...
#
#   :@computed_region_v3ji_vzam :@computed_region_c9xn_skx3  \
# 0                        2005                          13
#
#   :@computed_region_cfa7_hbpz :@computed_region_f73m_vb2k  \
# 0                          89                           1
#
#   :@computed_region_kh5x_g7w5 :@computed_region_yf9r_ed6g  \
# 0                          13                          13
#
#   :@computed_region_fvtq_wnma :@computed_region_b9k3_hpc2 violations_noted  \
# 0                          24                           1              NaN
#
#   :@computed_region_sjpq_96s8
# 0                         NaN
#
# [1 rows x 31 columns]

# %%
zip37208_perm.head(1)
# Out:
#              initiated_date     permit        permit_type  \
# 38  2023-03-28T13:51:28.000  202311391  EXCAVATION PERMIT
#
#                                    permit_description  status  \
# 38  REPAIR SEWER MAIN\nWO# 4472279\nCUT IS IN ALY ...  ACTIVE
#
#           on_street from_street   to_street location_address       city  ...  \
# 38  1020 JACKSON ST     563 ALY  11TH AVE N  1020 JACKSON ST  NASHVILLE  ...
#
#                                    company  \
# 38  METRO WATER / SYSTEM SERVICES DIVISION
#
#                                          days_to_work          latitude  \
# 38  Monday Tuesday Wednesday Thursday Friday Satur...  36.1700069998798
#
#             longitude                                    mapped_location  \
# 38  -86.7953345458244  {'type': 'Point', 'coordinates': [-86.79533454...
#
#    :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 38                           1                           1
#
#    :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz  \
# 38                          20                          51
#
#    :@computed_region_b9k3_hpc2
# 38                           7
#
# [1 rows x 27 columns]

# %%
comb_zip37208 = pd.merge(zip37208_perm,zip37208_comp, on='zip')

# %%
print(comb_zip37208.columns)
# Out:
# Index(['initiated_date', 'permit', 'permit_type', 'permit_description',
#        'status_x', 'on_street', 'from_street', 'to_street', 'location_address',
#        'city_x', 'zip', 'scope', 'scheduled_start', 'scheduled_end',
#        'permit_applicant_name', 'council_district_x',
#        'conditions_traffic_control', 'company', 'days_to_work', 'latitude',
#        'longitude', 'mapped_location_x', ':@computed_region_wvby_4s8j_x',
#        ':@computed_region_3aw5_2wv7_x', ':@computed_region_p6sk_2acq_x',
#        ':@computed_region_gxvr_9jxz_x', ':@computed_region_b9k3_hpc2_x',
#        'request', 'date_received', 'property_apn', 'property_address',
#        'city_y', 'state', 'property_owner', 'complaint_source',
#        'reported_problem', 'status_y', 'council_district_y',
#        'last_activity_date', 'last_activity', 'last_activity_result',
#        'mapped_location_y', ':@computed_region_wvby_4s8j_y',
#        ':@computed_region_3aw5_2wv7_y', ':@computed_region_p6sk_2acq_y',
#        ':@computed_region_gxvr_9jxz_y', ':@computed_region_gisn_y5cm',
#        ':@computed_region_v3ji_vzam', ':@computed_region_c9xn_skx3',
#        ':@computed_region_cfa7_hbpz', ':@computed_region_f73m_vb2k',
#        ':@computed_region_kh5x_g7w5', ':@computed_region_yf9r_ed6g',
#        ':@computed_region_fvtq_wnma', ':@computed_region_b9k3_hpc2_y',
#        'violations_noted', ':@computed_region_sjpq_96s8'],
#       dtype='object')
